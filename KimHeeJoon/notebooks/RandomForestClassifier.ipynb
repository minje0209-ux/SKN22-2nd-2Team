# %% [markdown]
# # Random Forest Classifier Baseline (Model Comparison) v3
#
# - 모델 종류 체급 비교 목적
#
# 평가 (Test set):
# - PR-AUC
# - Recall (Churn)
# - Accuracy
# - Confusion Matrix
# - Classification Report
# - Feature Importance

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_parquet('data/kkbox_train_feature_v3.parquet')

# %%
RANDOM_STATE = 719

ID_COL = "msno"
TARGET_COL = "is_churn"

CATEGORICAL_COLS = [
    "city", "gender", "registered_via", "last_payment_method",
    "has_ever_paid", "has_ever_cancelled", "is_free_user",
    "is_auto_renew_last"
]

NUMERICAL_COLS = [
    "reg_days",
    "num_days_active_w7", "total_secs_w7", "avg_secs_per_day_w7", "std_secs_w7",
    "num_songs_w7", "avg_songs_per_day_w7", "num_unq_w7", "num_25_w7", "num_100_w7",
    "short_play_w7", "skip_ratio_w7", "completion_ratio_w7", "short_play_ratio_w7", "variety_ratio_w7",
    "num_days_active_w14", "total_secs_w14", "avg_secs_per_day_w14", "std_secs_w14",
    "num_songs_w14", "avg_songs_per_day_w14", "num_unq_w14", "num_25_w14", "num_100_w14",
    "short_play_w14", "skip_ratio_w14", "completion_ratio_w14", "short_play_ratio_w14", "variety_ratio_w14",
    "num_days_active_w21", "total_secs_w21", "avg_secs_per_day_w21", "std_secs_w21",
    "num_songs_w21", "avg_songs_per_day_w21", "num_unq_w21", "num_25_w21", "num_100_w21",
    "short_play_w21", "skip_ratio_w21", "completion_ratio_w21", "short_play_ratio_w21", "variety_ratio_w21",
    "num_days_active_w30", "total_secs_w30", "avg_secs_per_day_w30", "std_secs_w30",
    "num_songs_w30", "avg_songs_per_day_w30", "num_unq_w30", "num_25_w30", "num_100_w30",
    "short_play_w30", "skip_ratio_w30", "completion_ratio_w30", "short_play_ratio_w30", "variety_ratio_w30",
    "secs_trend_w7_w30", "secs_trend_w14_w30", "days_trend_w7_w14", "days_trend_w7_w30",
    "songs_trend_w7_w30", "songs_trend_w14_w30", "skip_trend_w7_w30", "completion_trend_w7_w30",
    "days_since_last_payment", "days_since_last_cancel", "last_plan_days",
    "total_payment_count", "total_amount_paid", "avg_amount_per_payment",
    "unique_plan_count", "subscription_months_est", "payment_count_last_30d", "payment_count_last_90d",
]

FEATURE_COLS = CATEGORICAL_COLS + NUMERICAL_COLS

X = df[FEATURE_COLS].copy()
y = df[TARGET_COL].astype(int).copy()

# %% [markdown]
# ## 1. Train / Test Split

# %%
from sklearn.model_selection import train_test_split

X = df[FEATURE_COLS]
y = df[TARGET_COL].astype(int)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y,
)

print(X_train.shape, X_test.shape)
# Out:
# (688772, 83) (172194, 83)

# %% [markdown]
# ## 2. Column Groups

# %%
cat_cols = [c for c in CATEGORICAL_COLS if c in X_train.columns]
num_cols = [c for c in NUMERICAL_COLS if c in X_train.columns]

print(f"num_cols: {len(num_cols)}")
print(f"cat_cols: {len(cat_cols)}")
# Out:
# num_cols: 75
# cat_cols: 8

# %% [markdown]
# ## 3. Preprocessing (OHE only)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

X_train_t = preprocess.fit_transform(X_train)
X_test_t = preprocess.transform(X_test)

# %% [markdown]
# ## 4. Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=800,
    max_depth=None,
    max_features="sqrt",
    min_samples_split=2,
    min_samples_leaf=1,
    class_weight="balanced",
    n_jobs=-1,
    random_state=RANDOM_STATE,
)

# %% [markdown]
# ## 5. Train Model

# %%
rf_model.fit(X_train_t, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=800, n_jobs=-1,
#                        random_state=719)

# %% [markdown]
# ## 6. Test Evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    average_precision_score,
    recall_score,
    accuracy_score,
    confusion_matrix,
    classification_report,
)

y_proba = rf_model.predict_proba(X_test_t)[:, 1]
y_pred  = rf_model.predict(X_test_t)

print(f"PR-AUC: {average_precision_score(y_test, y_proba):.4f}")
print(f"Recall (Churn): {recall_score(y_test, y_pred):.4f}")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# PR-AUC: 0.9235
# Recall (Churn): 0.8107
# Accuracy: 0.9729

# %% [markdown]
# ## 7. Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm, index=["Actual 0", "Actual 1"], columns=["Pred 0", "Pred 1"])
# Out:
#           Pred 0  Pred 1
# Actual 0  154319    1585
# Actual 1    3084   13206

# %% [markdown]
# ## 8. Classification Report

# %%
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9804    0.9898    0.9851    155904
#            1     0.8928    0.8107    0.8498     16290
#
#     accuracy                         0.9729    172194
#    macro avg     0.9366    0.9003    0.9174    172194
# weighted avg     0.9721    0.9729    0.9723    172194

# %% [markdown]
# ## 9. Feature Importance (Impurity Decrease)

# %%
feature_names = preprocess.get_feature_names_out()
importances = rf_model.feature_importances_

imp_rf_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances,
}).sort_values("importance", ascending=False)

imp_rf_df
# Out:
#                            feature    importance
# 66     num__days_since_last_cancel  7.694808e-02
# 140      cat__has_ever_cancelled_1  7.384426e-02
# 69          num__total_amount_paid  7.283541e-02
# 72    num__subscription_months_est  6.539662e-02
# 139      cat__has_ever_cancelled_0  6.396427e-02
# 74     num__payment_count_last_90d  5.634683e-02
# 143      cat__is_auto_renew_last_0  4.977915e-02
# 144      cat__is_auto_renew_last_1  4.551291e-02
# 68        num__total_payment_count  4.092918e-02
# 70     num__avg_amount_per_payment  3.938822e-02
# 65    num__days_since_last_payment  3.743521e-02
# 73     num__payment_count_last_30d  3.347514e-02
# 137           cat__has_ever_paid_0  1.999428e-02
# 67             num__last_plan_days  1.714914e-02
# 0                    num__reg_days  1.403282e-02
# 142            cat__is_free_user_1  1.402353e-02
# 138           cat__has_ever_paid_1  1.387077e-02
# 141            cat__is_free_user_0  1.151927e-02
# 71          num__unique_plan_count  9.311740e-03
# 101          cat__registered_via_7  7.516744e-03
# 57          num__secs_trend_w7_w30  5.670305e-03
# 136  cat__last_payment_method_41.0  5.521612e-03
# 134  cat__last_payment_method_39.0  5.221201e-03
# 61         num__songs_trend_w7_w30  5.079657e-03
# 60          num__days_trend_w7_w30  5.055010e-03
# 2               num__total_secs_w7  4.961622e-03
# 5                num__num_songs_w7  4.466436e-03
# 7                  num__num_unq_w7  4.332679e-03
# 6        num__avg_songs_per_day_w7  4.305215e-03
# 59          num__days_trend_w7_w14  4.145370e-03
# 14           num__variety_ratio_w7  4.138955e-03
# 58         num__secs_trend_w14_w30  4.069485e-03
# 64    num__completion_trend_w7_w30  4.050822e-03
# 3         num__avg_secs_per_day_w7  4.012347e-03
# 62        num__songs_trend_w14_w30  3.822789e-03
# 63          num__skip_trend_w7_w30  3.487496e-03
# 56          num__variety_ratio_w30  3.439739e-03
# 127  cat__last_payment_method_32.0  3.439036e-03
# 46               num__std_secs_w30  3.336559e-03
# 45       num__avg_secs_per_day_w30  3.156755e-03
# 42          num__variety_ratio_w21  3.142396e-03
# 17       num__avg_secs_per_day_w14  3.133524e-03
# 16             num__total_secs_w14  3.130435e-03
# 28          num__variety_ratio_w14  3.105051e-03
# 20      num__avg_songs_per_day_w14  3.091863e-03
# 49                num__num_unq_w30  3.091425e-03
# 54       num__completion_ratio_w30  3.089210e-03
# 44             num__total_secs_w30  3.084479e-03
# 48      num__avg_songs_per_day_w30  3.076697e-03
# 9                  num__num_100_w7  3.064367e-03
# 47              num__num_songs_w30  3.043533e-03
# 19              num__num_songs_w14  3.038615e-03
# 12        num__completion_ratio_w7  3.031801e-03
# 18               num__std_secs_w14  3.019065e-03
# 32               num__std_secs_w21  2.972879e-03
# 23                num__num_100_w14  2.916869e-03
# 51                num__num_100_w30  2.874897e-03
# 11              num__skip_ratio_w7  2.867007e-03
# 53             num__skip_ratio_w30  2.846261e-03
# 21                num__num_unq_w14  2.844850e-03
# 55       num__short_play_ratio_w30  2.832227e-03
# 31       num__avg_secs_per_day_w21  2.812486e-03
# 34      num__avg_songs_per_day_w21  2.804129e-03
# 4                 num__std_secs_w7  2.735082e-03
# 30             num__total_secs_w21  2.728535e-03
# 35                num__num_unq_w21  2.706115e-03
# 75                     cat__city_1  2.697177e-03
# 25             num__skip_ratio_w14  2.681354e-03
# 40       num__completion_ratio_w21  2.679364e-03
# 13        num__short_play_ratio_w7  2.675969e-03
# 27       num__short_play_ratio_w14  2.667122e-03
# 52             num__short_play_w30  2.660338e-03
# 39             num__skip_ratio_w21  2.641810e-03
# 50                 num__num_25_w30  2.639995e-03
# 26       num__completion_ratio_w14  2.604985e-03
# 33              num__num_songs_w21  2.582443e-03
# 41       num__short_play_ratio_w21  2.532514e-03
# 8                   num__num_25_w7  2.495695e-03
# 37                num__num_100_w21  2.489983e-03
# 38             num__short_play_w21  2.358080e-03
# 10              num__short_play_w7  2.334446e-03
# 24             num__short_play_w14  2.316384e-03
# 43        num__num_days_active_w30  2.296903e-03
# 36                 num__num_25_w21  2.284951e-03
# 135  cat__last_payment_method_40.0  2.175587e-03
# 131  cat__last_payment_method_36.0  2.138309e-03
# 22                 num__num_25_w14  2.132281e-03
# 1          num__num_days_active_w7  2.097540e-03
# 133  cat__last_payment_method_38.0  1.944077e-03
# 98             cat__gender_unknown  1.871686e-03
# 29        num__num_days_active_w21  1.658285e-03
# 15        num__num_days_active_w14  1.552795e-03
# 102          cat__registered_via_9  1.365483e-03
# 132  cat__last_payment_method_37.0  1.012637e-03
# 100          cat__registered_via_4  1.009672e-03
# 124  cat__last_payment_method_29.0  8.381628e-04
# 99           cat__registered_via_3  7.565924e-04
# 96              cat__gender_female  7.289061e-04
# 97                cat__gender_male  7.199809e-04
# 86                    cat__city_13  5.347818e-04
# 78                     cat__city_5  5.207106e-04
# 77                     cat__city_4  4.533310e-04
# 95                    cat__city_22  4.408402e-04
# 112  cat__last_payment_method_15.0  3.873076e-04
# 88                    cat__city_15  3.865276e-04
# 125  cat__last_payment_method_30.0  3.211265e-04
# 79                     cat__city_6  3.102666e-04
# 129  cat__last_payment_method_34.0  2.972838e-04
# 87                    cat__city_14  2.303312e-04
# 128  cat__last_payment_method_33.0  2.148050e-04
# 81                     cat__city_8  1.967229e-04
# 82                     cat__city_9  1.821966e-04
# 84                    cat__city_11  1.708016e-04
# 85                    cat__city_12  1.653359e-04
# 91                    cat__city_18  1.479733e-04
# 83                    cat__city_10  1.305963e-04
# 94                    cat__city_21  1.260630e-04
# 90                    cat__city_17  1.208995e-04
# 76                     cat__city_3  1.185024e-04
# 117  cat__last_payment_method_20.0  1.043106e-04
# 126  cat__last_payment_method_31.0  1.029086e-04
# 80                     cat__city_7  8.360309e-05
# 118  cat__last_payment_method_21.0  7.051792e-05
# 122  cat__last_payment_method_27.0  5.787953e-05
# 123  cat__last_payment_method_28.0  5.136186e-05
# 89                    cat__city_16  5.058869e-05
# 113  cat__last_payment_method_16.0  4.711180e-05
# 116  cat__last_payment_method_19.0  4.044221e-05
# 103         cat__registered_via_13  3.628371e-05
# 119  cat__last_payment_method_22.0  3.541412e-05
# 120  cat__last_payment_method_23.0  3.440487e-05
# 130  cat__last_payment_method_35.0  2.694326e-05
# 93                    cat__city_20  1.979392e-05
# 107  cat__last_payment_method_10.0  1.731804e-05
# 114  cat__last_payment_method_17.0  1.460578e-05
# 110  cat__last_payment_method_13.0  1.153231e-05
# 109  cat__last_payment_method_12.0  8.536971e-06
# 92                    cat__city_19  5.307864e-06
# 121  cat__last_payment_method_26.0  4.928981e-06
# 108  cat__last_payment_method_11.0  3.917782e-06
# 115  cat__last_payment_method_18.0  2.131766e-06
# 111  cat__last_payment_method_14.0  1.750784e-06
# 106   cat__last_payment_method_8.0  1.025858e-08
# 105   cat__last_payment_method_6.0  7.537524e-20
# 104   cat__last_payment_method_3.0  6.664061e-20

# %%
import matplotlib.pyplot as plt

top_n = 20
top_imp = imp_rf_df.head(top_n)

plt.figure(figsize=(8, 6))
plt.barh(top_imp["feature"], top_imp["importance"])
plt.gca().invert_yaxis()  # 중요도가 높은 게 위로 오게
plt.xlabel("Importance")
plt.title("Top 20 Feature Importances (RandomForest)")
plt.show()

# %%
# imp_rf_df.to_csv(
#     "data/model_df/rf_feature_importance_19.csv",
#     index=False
# )
