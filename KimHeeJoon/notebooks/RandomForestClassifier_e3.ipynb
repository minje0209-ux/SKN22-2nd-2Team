# %% [markdown]
# # Random Forest Classifier Baseline (Model Comparison) v3
#
# - 모델 종류 체급 비교 목적
#
# 평가 (Test set):
# - PR-AUC
# - Recall (Churn)
# - Accuracy
# - Confusion Matrix
# - Classification Report
# - Feature Importance

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_parquet('data/kkbox_train_feature_v3.parquet')

# %%
RANDOM_STATE = 719

ID_COL = "msno"
TARGET_COL = "is_churn"

CATEGORICAL_COLS = [
    "city", "gender", "registered_via", "last_payment_method",
    "has_ever_paid", "has_ever_cancelled",
    "is_auto_renew_last",
    "is_free_user",
]

NUMERICAL_COLS = [
    "reg_days",

    # ======================
    # w7
    # ======================
    "num_days_active_w7", "total_secs_w7", "avg_secs_per_day_w7", "std_secs_w7",
    "num_songs_w7", "avg_songs_per_day_w7", "num_unq_w7", "num_25_w7", "num_100_w7",
    "short_play_w7", "skip_ratio_w7", "completion_ratio_w7", "short_play_ratio_w7", "variety_ratio_w7",

    # ======================
    # w14
    # ======================
    "num_days_active_w14", "total_secs_w14", "avg_secs_per_day_w14", "std_secs_w14",
    "num_songs_w14", "avg_songs_per_day_w14", "num_unq_w14", "num_25_w14", "num_100_w14",
    "short_play_w14", "skip_ratio_w14", "completion_ratio_w14", "short_play_ratio_w14", "variety_ratio_w14",

    # ======================
    # w21
    # ======================
    "num_days_active_w21", "total_secs_w21", "avg_secs_per_day_w21", "std_secs_w21",
    "num_songs_w21", "avg_songs_per_day_w21", "num_unq_w21", "num_25_w21", "num_100_w21",
    "short_play_w21", "skip_ratio_w21", "completion_ratio_w21", "short_play_ratio_w21", "variety_ratio_w21",

    # ======================
    # w30  (OFF → 주석 처리)
    # ======================
    # "num_days_active_w30", "total_secs_w30", "avg_secs_per_day_w30", "std_secs_w30",
    # "num_songs_w30", "avg_songs_per_day_w30", "num_unq_w30", "num_25_w30", "num_100_w30",
    # "short_play_w30", "skip_ratio_w30", "completion_ratio_w30", "short_play_ratio_w30", "variety_ratio_w30",

    # ======================
    # trend (주의: 상위 window에 종속됨)
    # ======================
    # w7–w14
    "days_trend_w7_w14",

    # w7–w30 / w14–w30 (w30 OFF 시 같이 OFF)
    # "secs_trend_w7_w30", "secs_trend_w14_w30",
    # "days_trend_w7_w30",
    # "songs_trend_w7_w30", "songs_trend_w14_w30",
    # "skip_trend_w7_w30", "completion_trend_w7_w30",

    # ======================
    # transactions (logs-only 실험 시 OFF)
    # ======================
    # "days_since_last_payment", "days_since_last_cancel", "last_plan_days",
    # "total_payment_count", "total_amount_paid", "avg_amount_per_payment",
    # "unique_plan_count", "subscription_months_est",
    # "payment_count_last_30d", "payment_count_last_90d",
]

FEATURE_COLS = CATEGORICAL_COLS + NUMERICAL_COLS

X = df[FEATURE_COLS].copy()
y = df[TARGET_COL].astype(int).copy()

# %% [markdown]
# ## 1. Train / Test Split

# %%
from sklearn.model_selection import train_test_split

X = df[FEATURE_COLS]
y = df[TARGET_COL].astype(int)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y,
)

print(X_train.shape, X_test.shape)
# Out:
# (688772, 52) (172194, 52)

# %% [markdown]
# ## 2. Column Groups

# %%
cat_cols = [c for c in CATEGORICAL_COLS if c in X_train.columns]
num_cols = [c for c in NUMERICAL_COLS if c in X_train.columns]

print(f"num_cols: {len(num_cols)}")
print(f"cat_cols: {len(cat_cols)}")
# Out:
# num_cols: 44
# cat_cols: 8

# %% [markdown]
# ## 3. Preprocessing (OHE only)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

X_train_t = preprocess.fit_transform(X_train)
X_test_t = preprocess.transform(X_test)

# %% [markdown]
# ## 4. Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=800,
    max_depth=None,
    max_features="sqrt",
    min_samples_split=2,
    min_samples_leaf=1,
    class_weight="balanced",
    n_jobs=-1,
    random_state=RANDOM_STATE,
)

# %% [markdown]
# ## 5. Train Model

# %%
rf_model.fit(X_train_t, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=800, n_jobs=-1,
#                        random_state=719)

# %% [markdown]
# ## 6. Test Evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    average_precision_score,
    recall_score,
    accuracy_score,
    confusion_matrix,
    classification_report,
)

y_proba = rf_model.predict_proba(X_test_t)[:, 1]
y_pred  = rf_model.predict(X_test_t)

print(f"PR-AUC: {average_precision_score(y_test, y_proba):.4f}")
print(f"Recall (Churn): {recall_score(y_test, y_pred):.4f}")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# PR-AUC: 0.7563
# Recall (Churn): 0.6146
# Accuracy: 0.9506

# %% [markdown]
# ## 7. Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm, index=["Actual 0", "Actual 1"], columns=["Pred 0", "Pred 1"])
# Out:
#           Pred 0  Pred 1
# Actual 0  153680    2224
# Actual 1    6278   10012

# %% [markdown]
# ## 8. Classification Report

# %%
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9608    0.9857    0.9731    155904
#            1     0.8182    0.6146    0.7020     16290
#
#     accuracy                         0.9506    172194
#    macro avg     0.8895    0.8002    0.8375    172194
# weighted avg     0.9473    0.9506    0.9474    172194

# %% [markdown]
# ## 9. Feature Importance (Impurity Decrease)

# %%
feature_names = preprocess.get_feature_names_out()
importances = rf_model.feature_importances_

imp_rf_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances,
}).sort_values("importance", ascending=False)

imp_rf_df
# Out:
#                            feature    importance
# 109      cat__has_ever_cancelled_1  1.097365e-01
# 108      cat__has_ever_cancelled_0  1.042413e-01
# 111      cat__is_auto_renew_last_1  7.289938e-02
# 110      cat__is_auto_renew_last_0  7.014788e-02
# 0                    num__reg_days  5.644830e-02
# 113            cat__is_free_user_1  3.413795e-02
# 112            cat__is_free_user_0  3.127332e-02
# 106           cat__has_ever_paid_0  3.111596e-02
# 107           cat__has_ever_paid_1  2.775402e-02
# 70           cat__registered_via_7  1.458451e-02
# 5                num__num_songs_w7  1.240137e-02
# 96   cat__last_payment_method_32.0  1.223059e-02
# 2               num__total_secs_w7  1.167648e-02
# 3         num__avg_secs_per_day_w7  1.141767e-02
# 7                  num__num_unq_w7  1.109491e-02
# 14           num__variety_ratio_w7  1.105844e-02
# 6        num__avg_songs_per_day_w7  1.039074e-02
# 12        num__completion_ratio_w7  9.777443e-03
# 43          num__days_trend_w7_w14  9.759876e-03
# 42          num__variety_ratio_w21  9.558213e-03
# 32               num__std_secs_w21  9.206794e-03
# 30             num__total_secs_w21  9.189501e-03
# 31       num__avg_secs_per_day_w21  9.158631e-03
# 28          num__variety_ratio_w14  9.066022e-03
# 17       num__avg_secs_per_day_w14  9.025907e-03
# 18               num__std_secs_w14  8.862495e-03
# 16             num__total_secs_w14  8.834582e-03
# 34      num__avg_songs_per_day_w21  8.730825e-03
# 40       num__completion_ratio_w21  8.704850e-03
# 21                num__num_unq_w14  8.657600e-03
# 35                num__num_unq_w21  8.646811e-03
# 9                  num__num_100_w7  8.636697e-03
# 13        num__short_play_ratio_w7  8.566916e-03
# 26       num__completion_ratio_w14  8.528458e-03
# 39             num__skip_ratio_w21  8.483664e-03
# 20      num__avg_songs_per_day_w14  8.431130e-03
# 105  cat__last_payment_method_41.0  8.422282e-03
# 41       num__short_play_ratio_w21  8.382026e-03
# 4                 num__std_secs_w7  8.366019e-03
# 11              num__skip_ratio_w7  8.351990e-03
# 33              num__num_songs_w21  8.336253e-03
# 19              num__num_songs_w14  8.288380e-03
# 25             num__skip_ratio_w14  8.265431e-03
# 27       num__short_play_ratio_w14  8.142114e-03
# 37                num__num_100_w21  8.059305e-03
# 23                num__num_100_w14  7.843410e-03
# 10              num__short_play_w7  7.637199e-03
# 38             num__short_play_w21  7.527176e-03
# 36                 num__num_25_w21  7.440011e-03
# 8                   num__num_25_w7  7.003241e-03
# 24             num__short_play_w14  6.865438e-03
# 22                 num__num_25_w14  6.391816e-03
# 100  cat__last_payment_method_36.0  5.914535e-03
# 1          num__num_days_active_w7  5.383696e-03
# 102  cat__last_payment_method_38.0  5.312028e-03
# 44                     cat__city_1  5.254054e-03
# 29        num__num_days_active_w21  5.147020e-03
# 67             cat__gender_unknown  4.150339e-03
# 15        num__num_days_active_w14  4.019401e-03
# 93   cat__last_payment_method_29.0  3.706643e-03
# 81   cat__last_payment_method_15.0  2.707757e-03
# 71           cat__registered_via_9  2.577318e-03
# 69           cat__registered_via_4  2.092842e-03
# 68           cat__registered_via_3  2.001994e-03
# 65              cat__gender_female  1.880972e-03
# 66                cat__gender_male  1.819165e-03
# 103  cat__last_payment_method_39.0  1.673743e-03
# 104  cat__last_payment_method_40.0  1.512876e-03
# 101  cat__last_payment_method_37.0  1.409730e-03
# 47                     cat__city_5  1.292088e-03
# 55                    cat__city_13  1.290473e-03
# 98   cat__last_payment_method_34.0  1.077448e-03
# 46                     cat__city_4  1.045194e-03
# 64                    cat__city_22  9.803791e-04
# 57                    cat__city_15  9.553348e-04
# 86   cat__last_payment_method_20.0  9.551431e-04
# 48                     cat__city_6  7.952169e-04
# 56                    cat__city_14  6.125540e-04
# 53                    cat__city_11  4.691070e-04
# 54                    cat__city_12  4.476357e-04
# 94   cat__last_payment_method_30.0  4.460599e-04
# 88   cat__last_payment_method_22.0  4.385868e-04
# 51                     cat__city_9  4.237216e-04
# 50                     cat__city_8  4.090907e-04
# 60                    cat__city_18  3.983801e-04
# 97   cat__last_payment_method_33.0  3.752221e-04
# 95   cat__last_payment_method_31.0  3.750328e-04
# 45                     cat__city_3  3.065748e-04
# 63                    cat__city_21  2.993409e-04
# 52                    cat__city_10  2.958710e-04
# 79   cat__last_payment_method_13.0  2.777632e-04
# 59                    cat__city_17  2.711947e-04
# 92   cat__last_payment_method_28.0  2.478109e-04
# 49                     cat__city_7  1.895774e-04
# 99   cat__last_payment_method_35.0  1.668122e-04
# 78   cat__last_payment_method_12.0  1.344880e-04
# 58                    cat__city_16  1.048238e-04
# 72          cat__registered_via_13  1.028425e-04
# 82   cat__last_payment_method_16.0  8.466054e-05
# 91   cat__last_payment_method_27.0  8.218510e-05
# 89   cat__last_payment_method_23.0  6.734866e-05
# 87   cat__last_payment_method_21.0  5.928202e-05
# 62                    cat__city_20  5.910800e-05
# 83   cat__last_payment_method_17.0  2.623578e-05
# 85   cat__last_payment_method_19.0  2.548650e-05
# 76   cat__last_payment_method_10.0  2.448783e-05
# 77   cat__last_payment_method_11.0  1.786606e-05
# 61                    cat__city_19  1.416359e-05
# 80   cat__last_payment_method_14.0  1.369792e-05
# 84   cat__last_payment_method_18.0  9.393996e-06
# 90   cat__last_payment_method_26.0  9.240731e-06
# 75    cat__last_payment_method_8.0  6.258757e-07
# 73    cat__last_payment_method_3.0  2.475697e-07
# 74    cat__last_payment_method_6.0  2.328966e-07

# %%
import matplotlib.pyplot as plt

top_n = 20
top_imp = imp_rf_df.head(top_n)

plt.figure(figsize=(8, 6))
plt.barh(top_imp["feature"], top_imp["importance"])
plt.gca().invert_yaxis()  # 중요도가 높은 게 위로 오게
plt.xlabel("Importance")
plt.title("Top 20 Feature Importances (RandomForest)")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# imp_rf_df.to_csv(
#     "../data/model_df/rf_feature_importance.csv",
#     index=False
# )
