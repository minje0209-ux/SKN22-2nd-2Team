# %% [markdown]
# ```python
# 'CatBoost e1'
#
# PR-AUC: 0.9152
# Recall (Churn): 0.9110
# Accuracy: 0.9543
#
#             Pred 0    Pred 1
# Actual 0    149477    6427
# Actual 1    1450      14840
#
# 'Catboost e2'
#
#             Pred 0    Pred 1
# Actual 0    140724    15180
# Actual 1    2419      13871
#
# 'Catboost 3.1'
#
# PR-AUC: 0.7895
# Recall (Churn): 0.8515
# Accuracy: 0.8962
#
#             Pred 0    Pred 1
# Actual 0    140441    15463
# Actual 1    2419      13871
