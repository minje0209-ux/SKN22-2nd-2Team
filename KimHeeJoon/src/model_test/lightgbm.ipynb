# %% [markdown]
# ```python
# 'lightGBM e1'
#
# PR-AUC: 0.9145
# Recall (Churn): 0.8822
# Accuracy: 0.9661
#
#             Pred 0    Pred 1
# Actual 0    151985    3919
# Actual 1    1919      14371
#
# 'lightGBM e2'
#
# PR-AUC: 0.7897
# Recall (Churn): 0.7980
# Accuracy: 0.9204
#
#             Pred 0    Pred 1
# Actual 0    145490    10414
# Actual 1    3291      12999
#
# 'lightGBM / e2.1'
#
# PR-AUC: 0.7766
# Recall (Churn): 0.7922
# Accuracy: 0.9184
#
#             Pred 0    Pred 1
# Actual 0    145242    10662
# Actual 1    3385      12905
#
# 'lightGBM e3.1'
#
# PR-AUC: 0.7874
# Recall (Churn): 0.8023
# Accuracy: 0.9179
#
#             Pred 0    Pred 1
# Actual 0    144980    10924
# Actual 1    3220      13070
# ```
