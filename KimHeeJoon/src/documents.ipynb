# %% [markdown]
# kkbox-bm-churn/
# │
# ├── data/
# │   ├── raw/
# │   │   ├── members_v3.csv
# │   │   ├── transactions_v2.csv
# │   │   ├── user_logs_v2.csv
# │   │   └── train_v2.csv
# │   │
# │   └── processed/
# │       └── feature_table.parquet
# │
# ├── src/
# │   ├── config.py
# │   ├── data_loader.py
# │   ├── feature_engineering.py
# │   ├── label_builder.py
# │   ├── modeling.py
# │   └── evaluation.py
# │
# └── run_pipeline.py
