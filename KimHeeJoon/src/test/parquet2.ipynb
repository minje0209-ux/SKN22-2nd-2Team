# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet('data/features_v2.parquet')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860966 entries, 0 to 860965
# Data columns (total 86 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   msno                     860966 non-null  string
#  1   city                     860966 non-null  int8
#  2   gender                   860966 non-null  category
#  3   registered_via           860966 non-null  int8
#  4   bd_clean                 386394 non-null  float32
#  5   is_churn                 860966 non-null  Int8
#  6   num_days_active_w7       860966 non-null  UInt8
#  7   total_secs_w7            860966 non-null  float32
#  8   avg_secs_per_day_w7      860966 non-null  float32
#  9   std_secs_w7              860966 non-null  float32
#  10  num_songs_w7             860966 non-null  UInt16
#  11  avg_songs_per_day_w7     860966 non-null  float32
#  12  num_unq_w7               860966 non-null  UInt16
#  13  num_25_w7                860966 non-null  UInt16
#  14  num_100_w7               860966 non-null  UInt16
#  15  short_play_w7            860966 non-null  UInt16
#  16  skip_ratio_w7            860966 non-null  float32
#  17  completion_ratio_w7      860966 non-null  float32
#  18  short_play_ratio_w7      860966 non-null  float32
#  19  variety_ratio_w7         860966 non-null  float32
#  20  num_days_active_w14      860966 non-null  UInt8
#  21  total_secs_w14           860966 non-null  float32
#  22  avg_secs_per_day_w14     860966 non-null  float32
#  23  std_secs_w14             860966 non-null  float32
#  24  num_songs_w14            860966 non-null  UInt16
#  25  avg_songs_per_day_w14    860966 non-null  float32
#  26  num_unq_w14              860966 non-null  UInt16
#  27  num_25_w14               860966 non-null  UInt16
#  28  num_100_w14              860966 non-null  UInt16
#  29  short_play_w14           860966 non-null  UInt16
#  30  skip_ratio_w14           860966 non-null  float32
#  31  completion_ratio_w14     860966 non-null  float32
#  32  short_play_ratio_w14     860966 non-null  float32
#  33  variety_ratio_w14        860966 non-null  float32
#  34  num_days_active_w21      860966 non-null  UInt8
#  35  total_secs_w21           860966 non-null  float32
#  36  avg_secs_per_day_w21     860966 non-null  float32
#  37  std_secs_w21             860966 non-null  float32
#  38  num_songs_w21            860966 non-null  UInt16
#  39  avg_songs_per_day_w21    860966 non-null  float32
#  40  num_unq_w21              860966 non-null  UInt16
#  41  num_25_w21               860966 non-null  UInt16
#  42  num_100_w21              860966 non-null  UInt16
#  43  short_play_w21           860966 non-null  UInt16
#  44  skip_ratio_w21           860966 non-null  float32
#  45  completion_ratio_w21     860966 non-null  float32
#  46  short_play_ratio_w21     860966 non-null  float32
#  47  variety_ratio_w21        860966 non-null  float32
#  48  num_days_active_w30      860966 non-null  UInt8
#  49  total_secs_w30           860966 non-null  float32
#  50  avg_secs_per_day_w30     860966 non-null  float32
#  51  std_secs_w30             860966 non-null  float32
#  52  num_songs_w30            860966 non-null  UInt16
#  53  avg_songs_per_day_w30    860966 non-null  float32
#  54  num_unq_w30              860966 non-null  UInt16
#  55  num_25_w30               860966 non-null  UInt16
#  56  num_100_w30              860966 non-null  UInt16
#  57  short_play_w30           860966 non-null  UInt16
#  58  skip_ratio_w30           860966 non-null  float32
#  59  completion_ratio_w30     860966 non-null  float32
#  60  short_play_ratio_w30     860966 non-null  float32
#  61  variety_ratio_w30        860966 non-null  float32
#  62  secs_trend_w7_w30        860966 non-null  float32
#  63  secs_trend_w14_w30       860966 non-null  float32
#  64  days_trend_w7_w14        860966 non-null  float32
#  65  days_trend_w7_w30        860966 non-null  float32
#  66  songs_trend_w7_w30       860966 non-null  float32
#  67  songs_trend_w14_w30      860966 non-null  float32
#  68  skip_trend_w7_w30        860966 non-null  float32
#  69  completion_trend_w7_w30  860966 non-null  float32
#  70  days_since_last_payment  825367 non-null  UInt16
#  71  has_ever_paid            860966 non-null  int8
#  72  days_since_last_cancel   825367 non-null  UInt16
#  73  has_ever_cancelled       860966 non-null  int8
#  74  is_auto_renew_last       860966 non-null  int8
#  75  last_plan_days           825367 non-null  UInt16
#  76  last_payment_method      825367 non-null  float64
#  77  is_free_user             860966 non-null  int8
#  78  total_payment_count      860966 non-null  UInt16
#  79  total_amount_paid        860966 non-null  UInt32
#  80  avg_amount_per_payment   860966 non-null  float32
#  81  unique_plan_count        860966 non-null  UInt8
#  82  subscription_months_est  860966 non-null  float32
#  83  payment_count_last_30d   860966 non-null  UInt8
#  84  payment_count_last_90d   860966 non-null  UInt8
#  85  reg_days                 860966 non-null  Int32
# dtypes: Int32(1), Int8(1), UInt16(24), UInt32(1), UInt8(7), category(1), float32(43), float64(1), int8(6), string(1)
# memory usage: 240.6 MB

# %%
def check_missing(df, name):
    print(f'[{name}]')
    missing = df.isnull().sum()
    missing = missing[missing > 0].sort_values(ascending=False)
    print(missing)
    print('-' * 40)

check_missing(df, 'df')
# Out:
# [df]
# bd_clean                   474572
# days_since_last_payment     35599
# days_since_last_cancel      35599
# last_plan_days              35599
# last_payment_method         35599
# dtype: int64
# ----------------------------------------

# %%
RANDOM_STATE = 719
np.random.seed(RANDOM_STATE)

D_COL = "msno"
TARGET_COL = "is_churn"

CATEGORICAL_COLS = [
    "city", "gender", "registered_via", "last_payment_method",
    "has_ever_paid", "has_ever_cancelled", "is_auto_renew_last", "is_free_user",
]

NUMERICAL_COLS = [
    "bd_clean", "reg_days",
    "num_days_active_w7", "total_secs_w7", "avg_secs_per_day_w7", "std_secs_w7",
    "num_songs_w7", "avg_songs_per_day_w7", "num_unq_w7", "num_25_w7", "num_100_w7",
    "short_play_w7", "skip_ratio_w7", "completion_ratio_w7", "short_play_ratio_w7", "variety_ratio_w7",
    "num_days_active_w14", "total_secs_w14", "avg_secs_per_day_w14", "std_secs_w14",
    "num_songs_w14", "avg_songs_per_day_w14", "num_unq_w14", "num_25_w14", "num_100_w14",
    "short_play_w14", "skip_ratio_w14", "completion_ratio_w14", "short_play_ratio_w14", "variety_ratio_w14",
    "num_days_active_w21", "total_secs_w21", "avg_secs_per_day_w21", "std_secs_w21",
    "num_songs_w21", "avg_songs_per_day_w21", "num_unq_w21", "num_25_w21", "num_100_w21",
    "short_play_w21", "skip_ratio_w21", "completion_ratio_w21", "short_play_ratio_w21", "variety_ratio_w21",
    "num_days_active_w30", "total_secs_w30", "avg_secs_per_day_w30", "std_secs_w30",
    "num_songs_w30", "avg_songs_per_day_w30", "num_unq_w30", "num_25_w30", "num_100_w30",
    "short_play_w30", "skip_ratio_w30", "completion_ratio_w30", "short_play_ratio_w30", "variety_ratio_w30",
    "secs_trend_w7_w30", "secs_trend_w14_w30", "days_trend_w7_w14", "days_trend_w7_w30",
    "songs_trend_w7_w30", "songs_trend_w14_w30", "skip_trend_w7_w30", "completion_trend_w7_w30",
    "days_since_last_payment", "days_since_last_cancel", "last_plan_days",
    "total_payment_count", "total_amount_paid", "avg_amount_per_payment",
    "unique_plan_count", "subscription_months_est", "payment_count_last_30d", "payment_count_last_90d",
]

FEATURE_COLS = CATEGORICAL_COLS + NUMERICAL_COLS

X = df[FEATURE_COLS].copy()
y = df[TARGET_COL].astype(int).copy()
print(X)
# Out:
#         city   gender  registered_via  last_payment_method  has_ever_paid  \
# 0          1  unknown               7                 41.0              1
# 1          4     male               9                 39.0              1
# 2         13     male               9                 40.0              1
# 3          1  unknown               7                 41.0              1
# 4          4   female               9                 36.0              1
# ...      ...      ...             ...                  ...            ...
# 860961     1  unknown               7                 41.0              1
# 860962     1  unknown               7                 41.0              1
# 860963     1  unknown               7                 41.0              1
# 860964     6   female               7                 41.0              1
# 860965     1  unknown               7                 41.0              1
#
#         has_ever_cancelled  is_auto_renew_last  is_free_user  bd_clean  \
# 0                        0                   1             0       NaN
# 1                        0                   1             0      30.0
# 2                        0                   1             0      63.0
# 3                        0                   1             0       NaN
# 4                        0                   1             0      28.0
# ...                    ...                 ...           ...       ...
# 860961                   0                   1             0       NaN
# 860962                   0                   1             0       NaN
# 860963                   0                   1             0       NaN
# 860964                   0                   1             0      26.0
# 860965                   0                   1             0       NaN
#
#         reg_days  ...  days_since_last_payment  days_since_last_cancel  \
# 0           2026  ...                        5                     999
# 1           2024  ...                        1                     999
# 2           2022  ...                        5                     999
# 3           2022  ...                        6                     999
# 4           2020  ...                       29                     999
# ...          ...  ...                      ...                     ...
# 860961       529  ...                       13                     999
# 860962       529  ...                       12                     999
# 860963       529  ...                       12                     999
# 860964       529  ...                       24                     999
# 860965       529  ...                       12                     999
#
#         last_plan_days  total_payment_count  total_amount_paid  \
# 0                   30                    1                129
# 1                   30                    2                298
# 2                   30                    1                149
# 3                   30                    1                149
# 4                   30                    1                180
# ...                ...                  ...                ...
# 860961              30                    1                 99
# 860962              30                    1                149
# 860963              30                    1                 99
# 860964              30                    1                149
# 860965              30                    1                 99
#
#         avg_amount_per_payment  unique_plan_count  subscription_months_est  \
# 0                        129.0                  1                      1.0
# 1                        149.0                  1                      2.0
# 2                        149.0                  1                      1.0
# 3                        149.0                  1                      1.0
# 4                        180.0                  1                      1.0
# ...                        ...                ...                      ...
# 860961                    99.0                  1                      1.0
# 860962                   149.0                  1                      1.0
# 860963                    99.0                  1                      1.0
# 860964                   149.0                  1                      1.0
# 860965                    99.0                  1                      1.0
#
#         payment_count_last_30d  payment_count_last_90d
# 0                            1                       1
# 1                            1                       2
# 2                            1                       1
# 3                            1                       1
# 4                            1                       1
# ...                        ...                     ...
# 860961                       1                       1
# 860962                       1                       1
# 860963                       1                       1
# 860964                       1                       1
# 860965                       1                       1
#
# [860966 rows x 84 columns]

# %%
print(y.value_counts())
# Out:
# is_churn
# 0    779518
# 1     81448
# Name: count, dtype: int64

# %%
# %pip install lightgbm
# Out:
# Collecting lightgbm
#   Using cached lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\playdata\miniconda3\envs\project-2nd\lib\site-packages (from lightgbm) (2.3.5)
# Requirement already satisfied: scipy in c:\users\playdata\miniconda3\envs\project-2nd\lib\site-packages (from lightgbm) (1.16.3)
# Using cached lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# categorical dtype 변환
for col in CATEGORICAL_COLS:
    X[col] = X[col].astype("category")

X_train, X_valid, y_train, y_valid = train_test_split(
    X, y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y
)

lgb_train = lgb.Dataset(
    X_train, y_train,
    categorical_feature=CATEGORICAL_COLS,
    free_raw_data=False
)

lgb_valid = lgb.Dataset(
    X_valid, y_valid,
    categorical_feature=CATEGORICAL_COLS,
    free_raw_data=False
)

params = {
    "objective": "binary",
    "metric": "AUCPR",
    "boosting_type": "gbdt",
    "learning_rate": 0.05,
    "num_leaves": 64,
    "max_depth": -1,
    "min_data_in_leaf": 100,
    "feature_fraction": 0.8,
    "bagging_fraction": 0.8,
    "bagging_freq": 5,
    "lambda_l1": 1.0,
    "lambda_l2": 1.0,
    "seed": RANDOM_STATE,
    "verbosity": -1
}

model = lgb.train(
    params,
    lgb_train,
    num_boost_round=2000,
    valid_sets=[lgb_train, lgb_valid],
    valid_names=["train", "valid"],
    callbacks=[
        lgb.early_stopping(stopping_rounds=100),
        lgb.log_evaluation(period=100)
    ]
)

# 평가
valid_pred = model.predict(X_valid)
auc = roc_auc_score(y_valid, valid_pred)
print("Valid AUC:", auc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 45
#      22 lgb_valid = lgb.Dataset(
#      23     X_valid, y_valid,
#      24     categorical_feature=CATEGORICAL_COLS,
#      25     free_raw_data=False
#      26 )
#      28 params = {
#      29     "objective": "binary",
#      30     "metric": "AUCPR",
#    (...)     42     "verbosity": -1
#      43 }
# ---> 45 model = lgb.train(
#      46     params,
#      47     lgb_train,
#      48     num_boost_round=2000,
#      49     valid_sets=[lgb_train, lgb_valid],
#      50     valid_names=["train", "valid"],
#      51     callbacks=[
#      52         lgb.early_stopping(stopping_rounds=100),
#      53         lgb.log_evaluation(period=100)
#      54     ]
#      55 )
#      57 # 평가
#      58 valid_pred = model.predict(X_valid)
#
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\lightgbm\engine.py:332, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     330 try:
#     331     for cb in callbacks_after_iter:
# --> 332         cb(
#     333             callback.CallbackEnv(
#     334                 model=booster,
#     335                 params=params,
#     336                 iteration=i,
#     337                 begin_iteration=init_iteration,
#     338                 end_iteration=init_iteration + num_boost_round,
#     339                 evaluation_result_list=evaluation_result_list,
#     340             )
#     341         )
#     342 except callback.EarlyStopException as earlyStopException:
#     343     booster.best_iteration = earlyStopException.best_iteration + 1
#
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\lightgbm\callback.py:404, in _EarlyStoppingCallback.__call__(self, env)
#     402 def __call__(self, env: CallbackEnv) -> None:
#     403     if env.iteration == env.begin_iteration:
# --> 404         self._init(env)
#     405     if not self.enabled:
#     406         return
#
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\lightgbm\callback.py:328, in _EarlyStoppingCallback._init(self, env)
#     326 def _init(self, env: CallbackEnv) -> None:
#     327     if env.evaluation_result_list is None or env.evaluation_result_list == []:
# --> 328         raise ValueError("For early stopping, at least one dataset and eval metric is required for evaluation")
#     330     is_dart = any(env.params.get(alias, "") == "dart" for alias in _ConfigAliases.get("boosting"))
#     331     if is_dart:
#
# ValueError: For early stopping, at least one dataset and eval metric is required for evaluation

# %%
import numpy as np
from sklearn.metrics import precision_recall_curve, f1_score

proba = model.predict(X_valid)

precision, recall, thresholds = precision_recall_curve(y_valid, proba)

f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)
best_idx = np.argmax(f1_scores)

best_threshold = thresholds[best_idx]
print("Best threshold:", best_threshold)
print("Precision:", precision[best_idx])
print("Recall:", recall[best_idx])
print("F1:", f1_scores[best_idx])
# Out:
# Best threshold: 0.4575809392725924
# Precision: 0.8759155803848542
# Recall: 0.8662369551872314
# F1: 0.8710493822160648

# %%
from sklearn.metrics import confusion_matrix

y_pred = (proba >= best_threshold).astype(int)

cm = confusion_matrix(y_valid, y_pred)
cm = pd.DataFrame(cm)
cm
# Out:
#         0      1
# 0  153905   1999
# 1    2179  14111

# %%
import pandas as pd

fi = pd.DataFrame({
    "feature": model.feature_name(),
    "importance": model.feature_importance(importance_type="gain")
}).sort_values("importance", ascending=False)

fi.head(20)
# Out:
#                     feature    importance
# 75   days_since_last_cancel  1.030906e+06
# 76           last_plan_days  4.734847e+05
# 74  days_since_last_payment  2.608842e+05
# 3       last_payment_method  1.451569e+05
# 83   payment_count_last_90d  1.178528e+05
# 5        has_ever_cancelled  1.067290e+05
# 78        total_amount_paid  1.062151e+05
# 6        is_auto_renew_last  1.001823e+05
# 77      total_payment_count  8.676794e+04
# 81  subscription_months_est  6.137875e+04
# 79   avg_amount_per_payment  5.353242e+04
# 82   payment_count_last_30d  4.507577e+04
# 70       songs_trend_w7_w30  4.163372e+04
# 14             num_songs_w7  3.353141e+04
# 15     avg_songs_per_day_w7  2.300967e+04
# 9                  reg_days  1.946510e+04
# 25           total_secs_w14  1.295604e+04
# 2            registered_via  8.214197e+03
# 69        days_trend_w7_w30  7.270436e+03
# 44              num_unq_w21  5.239466e+03

# %%
# 예시: 기준 날짜 기준 분할
train_df = df[df["base_date"] < "2017-03-01"]
valid_df = df[df["base_date"] >= "2017-03-01"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'base_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 # 예시: 기준 날짜 기준 분할
# ----> 2 train_df = df[df["base_date"] < "2017-03-01"]
#       3 valid_df = df[df["base_date"] >= "2017-03-01"]
#
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'base_date'

# %%
df["churn_proba"] = model.predict(df[FEATURE_COLS])
df["churn_pred"] = (df["churn_proba"] >= best_threshold).astype(int)

# 이탈 위험 TOP 1%
high_risk = df.sort_values("churn_proba", ascending=False).head(int(len(df)*0.01))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df["churn_proba"] = model.predict(df[FEATURE_COLS])
#       2 df["churn_pred"] = (df["churn_proba"] >= best_threshold).astype(int)
#       4 # 이탈 위험 TOP 1%
#
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\lightgbm\basic.py:4767, in Booster.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features, **kwargs)
#    4765     else:
#    4766         num_iteration = -1
# -> 4767 return predictor.predict(
#    4768     data=data,
#    4769     start_iteration=start_iteration,
#    4770     num_iteration=num_iteration,
#    4771     raw_score=raw_score,
#    4772     pred_leaf=pred_leaf,
#    4773     pred_contrib=pred_contrib,
#    4774     data_has_header=data_has_header,
#    4775     validate_features=validate_features,
#    4776 )
#
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\lightgbm\basic.py:1158, in _InnerPredictor.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features)
#    1149     _safe_call(
#    1150         _LIB.LGBM_BoosterValidateFeatureNames(
#    1151             self._handle,
#    (...)   1154         )
#    1155     )
#    1157 if isinstance(data, pd_DataFrame):
# -> 1158     data = _data_from_pandas(
#    1159         data=data,
#    1160         feature_name="auto",
#    1161         categorical_feature="auto",
#    1162         pandas_categorical=self.pandas_categorical,
#    1163     )[0]
#    1165 predict_type = _C_API_PREDICT_NORMAL
#    1166 if raw_score:
#
# File c:\Users\Playdata\miniconda3\envs\project-2nd\Lib\site-packages\lightgbm\basic.py:851, in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     849 else:
#     850     if len(cat_cols) != len(pandas_categorical):
# --> 851         raise ValueError("train and valid dataset categorical_feature do not match.")
#     852     for col, category in zip(cat_cols, pandas_categorical):
#     853         if list(data[col].cat.categories) != list(category):
#
# ValueError: train and valid dataset categorical_feature do not match.
