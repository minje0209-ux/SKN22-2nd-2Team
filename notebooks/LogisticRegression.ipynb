# %% [markdown]
# # Logistic Regression Baseline (Model Comparison) v3
#
# - 모델 종류 체급 비교 목적
#
# 평가 (Test set):
# - PR-AUC
# - Recall (Churn)
# - Accuracy
# - Confusion Matrix
# - Classification Report
# - Feature Importance (coef)

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_parquet('../data/processed/kkbox_train_feature_v3.parquet')

# %%
RANDOM_STATE = 719

ID_COL = "msno"
TARGET_COL = "is_churn"

CATEGORICAL_COLS = [
    "city", "gender", "registered_via", "last_payment_method",
    "has_ever_paid", "has_ever_cancelled",
    "is_auto_renew_last",
    "is_free_user",
]

NUMERICAL_COLS = [
    "reg_days",

    # ======================
    # w7
    # ======================
    "num_days_active_w7", "total_secs_w7", "avg_secs_per_day_w7", "std_secs_w7",
    "num_songs_w7", "avg_songs_per_day_w7", "num_unq_w7", "num_25_w7", "num_100_w7",
    "short_play_w7", "skip_ratio_w7", "completion_ratio_w7", "short_play_ratio_w7", "variety_ratio_w7",

    # ======================
    # w14
    # ======================
    "num_days_active_w14", "total_secs_w14", "avg_secs_per_day_w14", "std_secs_w14",
    "num_songs_w14", "avg_songs_per_day_w14", "num_unq_w14", "num_25_w14", "num_100_w14",
    "short_play_w14", "skip_ratio_w14", "completion_ratio_w14", "short_play_ratio_w14", "variety_ratio_w14",

    # ======================
    # w21
    # ======================
    "num_days_active_w21", "total_secs_w21", "avg_secs_per_day_w21", "std_secs_w21",
    "num_songs_w21", "avg_songs_per_day_w21", "num_unq_w21", "num_25_w21", "num_100_w21",
    "short_play_w21", "skip_ratio_w21", "completion_ratio_w21", "short_play_ratio_w21", "variety_ratio_w21",

    # ======================
    # w30  (OFF → 주석 처리)
    # ======================
    "num_days_active_w30", "total_secs_w30", "avg_secs_per_day_w30", "std_secs_w30",
    "num_songs_w30", "avg_songs_per_day_w30", "num_unq_w30", "num_25_w30", "num_100_w30",
    "short_play_w30", "skip_ratio_w30", "completion_ratio_w30", "short_play_ratio_w30", "variety_ratio_w30",

    # ======================
    # trend (주의: 상위 window에 종속됨)
    # ======================
    # w7–w14
    "days_trend_w7_w14",

    # w7–w30 / w14–w30 (w30 OFF 시 같이 OFF)
    "secs_trend_w7_w30", "secs_trend_w14_w30",
    "days_trend_w7_w30",
    "songs_trend_w7_w30", "songs_trend_w14_w30",
    "skip_trend_w7_w30", "completion_trend_w7_w30",

    # ======================
    # transactions (logs-only 실험 시 OFF)
    # ======================
    "days_since_last_payment", "days_since_last_cancel", "last_plan_days",
    "total_payment_count", "total_amount_paid", "avg_amount_per_payment",
    "unique_plan_count", "subscription_months_est",
    "payment_count_last_30d", "payment_count_last_90d",
]

FEATURE_COLS = CATEGORICAL_COLS + NUMERICAL_COLS

X = df[FEATURE_COLS].copy()
y = df[TARGET_COL].astype(int).copy()

# %% [markdown]
# ## 1. Train / Test Split

# %%
from sklearn.model_selection import train_test_split

X = df[FEATURE_COLS]
y = df[TARGET_COL].astype(int)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y,
)

print(X_train.shape, X_test.shape)
# Out:
# (688772, 83) (172194, 83)

# %% [markdown]
# ## 2. Column Groups

# %%
cat_cols = [c for c in CATEGORICAL_COLS if c in X_train.columns]
num_cols = [c for c in NUMERICAL_COLS if c in X_train.columns]

print(f"num_cols: {len(num_cols)}")
print(f"cat_cols: {len(cat_cols)}")
# Out:
# num_cols: 75
# cat_cols: 8

# %% [markdown]
# ## 3. Preprocessing (OHE + Scale)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

numeric_tf = Pipeline(steps=[
    ("scaler", StandardScaler(with_mean=False)),
])

categorical_tf = Pipeline(steps=[
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=True)),
])

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_tf, num_cols),
        ("cat", categorical_tf, cat_cols),
    ],
    remainder="drop",
)

# %% [markdown]
# ## 4. Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(
    max_iter=2000,
    n_jobs=-1,
    class_weight="balanced",
)

# %% [markdown]
# ## 5. Train Model

# %%
from sklearn.pipeline import Pipeline

lr_clf = Pipeline(steps=[
    ("prep", preprocess),
    ("model", lr),
])

lr_clf.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/project-2nd/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler(with_mean=False))]),
#                                                   ['reg_days',
#                                                    'num_days_active_w7',
#                                                    'total_secs_w7',
#                                                    'avg_secs_per_day_w7',
#                                                    'std_secs_w7',
#                                                    'num_songs_w7',
#                                                    'avg_songs_per_day_w7',
#                                                    'num_unq_w7', 'num_25_w7',
#                                                    'num_100_w7',
#                                                    'short_play_w7',
#                                                    'skip_ratio_w7',
#                                                    'completion_ratio_w7',
#                                                    'short_play...
#                                                    'short_play_ratio_w14',
#                                                    'variety_ratio_w14',
#                                                    'num_days_active_w21', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['city', 'gender',
#                                                    'registered_via',
#                                                    'last_payment_method',
#                                                    'has_ever_paid',
#                                                    'has_ever_cancelled',
#                                                    'is_auto_renew_last',
#                                                    'is_free_user'])])),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=2000,
#                                     n_jobs=-1))])

# %% [markdown]
# ## 6. Test Evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    average_precision_score,
    recall_score,
    accuracy_score,
    confusion_matrix,
    classification_report,
)

y_proba = lr_clf.predict_proba(X_test)[:, 1]
y_pred  = lr_clf.predict(X_test)

print(f"PR-AUC: {average_precision_score(y_test, y_proba):.4f}")
print(f"Recall (Churn): {recall_score(y_test, y_pred):.4f}")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# PR-AUC: 0.8377
# Recall (Churn): 0.9077
# Accuracy: 0.9339

# %% [markdown]
# ## 7. Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm, index=["Actual 0", "Actual 1"], columns=["Pred 0", "Pred 1"])
# Out:
#           Pred 0  Pred 1
# Actual 0  146019    9885
# Actual 1    1503   14787

# %% [markdown]
# ## 8. Classification Report

# %%
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9898    0.9366    0.9625    155904
#            1     0.5993    0.9077    0.7220     16290
#
#     accuracy                         0.9339    172194
#    macro avg     0.7946    0.9222    0.8422    172194
# weighted avg     0.9529    0.9339    0.9397    172194

# %% [markdown]
# ## 9. Feature Importance (Coefficients)

# %%
feature_names = lr_clf.named_steps["prep"].get_feature_names_out()
coef = lr_clf.named_steps["model"].coef_[0]

imp_lr_df = pd.DataFrame({
    "feature": feature_names,
    "coef": coef,
    "abs_coef": np.abs(coef),
}).sort_values("abs_coef", ascending=False)

imp_lr_df
# Out:
#                            feature      coef  abs_coef
# 70     num__avg_amount_per_payment  3.525171  3.525171
# 144            cat__is_free_user_1  3.351787  3.351787
# 137           cat__has_ever_paid_0  3.351787  3.351787
# 116  cat__last_payment_method_19.0 -2.840781  2.840781
# 118  cat__last_payment_method_21.0 -2.789795  2.789795
# 143            cat__is_free_user_0 -2.571980  2.571980
# 138           cat__has_ever_paid_1 -2.571980  2.571980
# 121  cat__last_payment_method_26.0  2.290687  2.290687
# 134  cat__last_payment_method_39.0 -2.218380  2.218380
# 127  cat__last_payment_method_32.0  2.167229  2.167229
# 130  cat__last_payment_method_35.0  1.900928  1.900928
# 66     num__days_since_last_cancel -1.836389  1.836389
# 142      cat__is_auto_renew_last_1  1.654927  1.654927
# 74     num__payment_count_last_90d  1.526565  1.526565
# 114  cat__last_payment_method_17.0  1.286735  1.286735
# 69          num__total_amount_paid -1.276054  1.276054
# 133  cat__last_payment_method_38.0  1.044572  1.044572
# 126  cat__last_payment_method_31.0 -0.990888  0.990888
# 73     num__payment_count_last_30d -0.953471  0.953471
# 129  cat__last_payment_method_34.0 -0.901647  0.901647
# 141      cat__is_auto_renew_last_0 -0.875120  0.875120
# 123  cat__last_payment_method_28.0  0.870595  0.870595
# 112  cat__last_payment_method_15.0  0.860904  0.860904
# 111  cat__last_payment_method_14.0 -0.843891  0.843891
# 135  cat__last_payment_method_40.0  0.841736  0.841736
# 128  cat__last_payment_method_33.0 -0.813768  0.813768
# 136  cat__last_payment_method_41.0  0.811936  0.811936
# 120  cat__last_payment_method_23.0 -0.803612  0.803612
# 65    num__days_since_last_payment  0.728932  0.728932
# 139      cat__has_ever_cancelled_0  0.711750  0.711750
# 68        num__total_payment_count  0.597169  0.597169
# 72    num__subscription_months_est  0.546162  0.546162
# 100          cat__registered_via_4  0.500864  0.500864
# 131  cat__last_payment_method_36.0  0.386777  0.386777
# 33              num__num_songs_w21 -0.374657  0.374657
# 35                num__num_unq_w21  0.374075  0.374075
# 9                  num__num_100_w7  0.344138  0.344138
# 43        num__num_days_active_w30  0.342913  0.342913
# 67             num__last_plan_days  0.337409  0.337409
# 107  cat__last_payment_method_10.0  0.324981  0.324981
# 89                    cat__city_16  0.316773  0.316773
# 117  cat__last_payment_method_20.0  0.314927  0.314927
# 93                    cat__city_20 -0.311291  0.311291
# 97                cat__gender_male  0.303304  0.303304
# 20      num__avg_songs_per_day_w14 -0.301038  0.301038
# 125  cat__last_payment_method_30.0  0.289502  0.289502
# 2               num__total_secs_w7 -0.279657  0.279657
# 47              num__num_songs_w30 -0.262128  0.262128
# 80                     cat__city_7  0.256719  0.256719
# 122  cat__last_payment_method_27.0 -0.248079  0.248079
# 98             cat__gender_unknown  0.247153  0.247153
# 103         cat__registered_via_13  0.244724  0.244724
# 108  cat__last_payment_method_11.0 -0.244561  0.244561
# 17       num__avg_secs_per_day_w14  0.239389  0.239389
# 24             num__short_play_w14  0.239184  0.239184
# 31       num__avg_secs_per_day_w21 -0.233082  0.233082
# 23                num__num_100_w14  0.230245  0.230245
# 96              cat__gender_female  0.229350  0.229350
# 0                    num__reg_days  0.229033  0.229033
# 21                num__num_unq_w14 -0.202914  0.202914
# 22                 num__num_25_w14 -0.200892  0.200892
# 132  cat__last_payment_method_37.0 -0.195255  0.195255
# 110  cat__last_payment_method_13.0  0.191533  0.191533
# 52             num__short_play_w30  0.172869  0.172869
# 37                num__num_100_w21  0.168419  0.168419
# 77                     cat__city_4  0.165283  0.165283
# 92                    cat__city_19 -0.164010  0.164010
# 8                   num__num_25_w7  0.158597  0.158597
# 10              num__short_play_w7 -0.155447  0.155447
# 15        num__num_days_active_w14 -0.150517  0.150517
# 1          num__num_days_active_w7 -0.142905  0.142905
# 26       num__completion_ratio_w14 -0.142828  0.142828
# 51                num__num_100_w30  0.138217  0.138217
# 29        num__num_days_active_w21 -0.132848  0.132848
# 81                     cat__city_8  0.132571  0.132571
# 49                num__num_unq_w30 -0.130564  0.130564
# 46               num__std_secs_w30  0.128616  0.128616
# 62        num__songs_trend_w14_w30  0.126729  0.126729
# 109  cat__last_payment_method_12.0  0.126006  0.126006
# 27       num__short_play_ratio_w14 -0.123674  0.123674
# 115  cat__last_payment_method_18.0 -0.115690  0.115690
# 71          num__unique_plan_count -0.113527  0.113527
# 79                     cat__city_6  0.107754  0.107754
# 59         num__secs_trend_w14_w30 -0.107260  0.107260
# 44             num__total_secs_w30  0.107005  0.107005
# 82                     cat__city_9  0.106266  0.106266
# 95                    cat__city_22  0.100688  0.100688
# 34      num__avg_songs_per_day_w21  0.099775  0.099775
# 88                    cat__city_15  0.093525  0.093525
# 41       num__short_play_ratio_w21 -0.092601  0.092601
# 78                     cat__city_5  0.092141  0.092141
# 91                    cat__city_18 -0.091517  0.091517
# 3         num__avg_secs_per_day_w7 -0.087396  0.087396
# 11              num__skip_ratio_w7 -0.086801  0.086801
# 102          cat__registered_via_9 -0.073036  0.073036
# 48      num__avg_songs_per_day_w30  0.071826  0.071826
# 40       num__completion_ratio_w21 -0.071363  0.071363
# 58          num__secs_trend_w7_w30  0.069046  0.069046
# 18               num__std_secs_w14 -0.068988  0.068988
# 140      cat__has_ever_cancelled_1  0.068057  0.068057
# 53             num__skip_ratio_w30 -0.067140  0.067140
# 99           cat__registered_via_3  0.065983  0.065983
# 86                    cat__city_13  0.061099  0.061099
# 13        num__short_play_ratio_w7  0.060980  0.060980
# 61         num__songs_trend_w7_w30 -0.058848  0.058848
# 5                num__num_songs_w7 -0.057935  0.057935
# 64    num__completion_trend_w7_w30 -0.057925  0.057925
# 83                    cat__city_10  0.057637  0.057637
# 57          num__days_trend_w7_w14 -0.054569  0.054569
# 124  cat__last_payment_method_29.0  0.054341  0.054341
# 90                    cat__city_17 -0.051948  0.051948
# 25             num__skip_ratio_w14  0.051244  0.051244
# 55       num__short_play_ratio_w30  0.050905  0.050905
# 32               num__std_secs_w21 -0.050647  0.050647
# 101          cat__registered_via_7  0.041273  0.041273
# 60          num__days_trend_w7_w30  0.038057  0.038057
# 42          num__variety_ratio_w21 -0.035133  0.035133
# 87                    cat__city_14  0.035115  0.035115
# 54       num__completion_ratio_w30  0.035079  0.035079
# 36                 num__num_25_w21  0.034464  0.034464
# 28          num__variety_ratio_w14 -0.033948  0.033948
# 7                  num__num_unq_w7  0.033182  0.033182
# 76                     cat__city_3 -0.031615  0.031615
# 75                     cat__city_1 -0.030300  0.030300
# 119  cat__last_payment_method_22.0  0.027716  0.027716
# 63          num__skip_trend_w7_w30 -0.027570  0.027570
# 84                    cat__city_11 -0.023611  0.023611
# 85                    cat__city_12 -0.021121  0.021121
# 94                    cat__city_21 -0.020353  0.020353
# 39             num__skip_ratio_w21  0.018760  0.018760
# 16             num__total_secs_w14  0.014298  0.014298
# 56          num__variety_ratio_w30  0.014269  0.014269
# 45       num__avg_secs_per_day_w30 -0.012275  0.012275
# 12        num__completion_ratio_w7 -0.011766  0.011766
# 38             num__short_play_w21 -0.011766  0.011766
# 50                 num__num_25_w30 -0.011565  0.011565
# 113  cat__last_payment_method_16.0 -0.005172  0.005172
# 19              num__num_songs_w14 -0.004774  0.004774
# 6        num__avg_songs_per_day_w7  0.002449  0.002449
# 4                 num__std_secs_w7  0.002129  0.002129
# 30             num__total_secs_w21 -0.001527  0.001527
# 14           num__variety_ratio_w7 -0.000652  0.000652
# 106   cat__last_payment_method_8.0  0.000119  0.000119
# 104   cat__last_payment_method_3.0  0.000060  0.000060
# 105   cat__last_payment_method_6.0  0.000043  0.000043

# %%
# imp_lr_df.to_csv(
#     "../data/model_df/lr_feature_importance_e1.csv",
#     index=False
# )
