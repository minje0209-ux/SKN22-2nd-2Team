# %% [markdown]
# # Logistic Regression Baseline (Model Comparison) v3
#
# - 모델 종류 체급 비교 목적
#
# 평가 (Test set):
# - PR-AUC
# - Recall (Churn)
# - Accuracy
# - Confusion Matrix
# - Classification Report
# - Feature Importance (coef)

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_parquet('../data/processed/kkbox_train_feature_v3.parquet')

# %%
RANDOM_STATE = 719

ID_COL = "msno"
TARGET_COL = "is_churn"

CATEGORICAL_COLS = [
    "city", "gender", "registered_via", "last_payment_method",
    "has_ever_paid", "has_ever_cancelled", "is_auto_renew_last", "is_free_user",
]

NUMERICAL_COLS = [
    "reg_days",
    "num_days_active_w7", "total_secs_w7", "avg_secs_per_day_w7", "std_secs_w7",
    "num_songs_w7", "avg_songs_per_day_w7", "num_unq_w7", "num_25_w7", "num_100_w7",
    "short_play_w7", "skip_ratio_w7", "completion_ratio_w7", "short_play_ratio_w7", "variety_ratio_w7",
    "num_days_active_w14", "total_secs_w14", "avg_secs_per_day_w14", "std_secs_w14",
    "num_songs_w14", "avg_songs_per_day_w14", "num_unq_w14", "num_25_w14", "num_100_w14",
    "short_play_w14", "skip_ratio_w14", "completion_ratio_w14", "short_play_ratio_w14", "variety_ratio_w14",
    "num_days_active_w21", "total_secs_w21", "avg_secs_per_day_w21", "std_secs_w21",
    "num_songs_w21", "avg_songs_per_day_w21", "num_unq_w21", "num_25_w21", "num_100_w21",
    "short_play_w21", "skip_ratio_w21", "completion_ratio_w21", "short_play_ratio_w21", "variety_ratio_w21",
    "num_days_active_w30", "total_secs_w30", "avg_secs_per_day_w30", "std_secs_w30",
    "num_songs_w30", "avg_songs_per_day_w30", "num_unq_w30", "num_25_w30", "num_100_w30",
    "short_play_w30", "skip_ratio_w30", "completion_ratio_w30", "short_play_ratio_w30", "variety_ratio_w30",
    "secs_trend_w7_w30", "secs_trend_w14_w30", "days_trend_w7_w14", "days_trend_w7_w30",
    "songs_trend_w7_w30", "songs_trend_w14_w30", "skip_trend_w7_w30", "completion_trend_w7_w30",
    "days_since_last_payment", "days_since_last_cancel", "last_plan_days",
    "total_payment_count", "total_amount_paid", "avg_amount_per_payment",
    "unique_plan_count", "subscription_months_est", "payment_count_last_30d", "payment_count_last_90d",
]

FEATURE_COLS = CATEGORICAL_COLS + NUMERICAL_COLS

X = df[FEATURE_COLS].copy()
y = df[TARGET_COL].astype(int).copy()

# %% [markdown]
# ## 1. Train / Test Split

# %%
from sklearn.model_selection import train_test_split

X = df[FEATURE_COLS]
y = df[TARGET_COL].astype(int)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y,
)

print(X_train.shape, X_test.shape)
# Out:
# (688772, 83) (172194, 83)

# %% [markdown]
# ## 2. Column Groups

# %%
cat_cols = [c for c in CATEGORICAL_COLS if c in X_train.columns]
num_cols = [c for c in NUMERICAL_COLS if c in X_train.columns]

print(f"num_cols: {len(num_cols)}")
print(f"cat_cols: {len(cat_cols)}")
# Out:
# num_cols: 75
# cat_cols: 8

# %% [markdown]
# ## 3. Preprocessing (OHE + Scale)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

numeric_tf = Pipeline(steps=[
    ("scaler", StandardScaler(with_mean=False)),
])

categorical_tf = Pipeline(steps=[
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=True)),
])

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_tf, num_cols),
        ("cat", categorical_tf, cat_cols),
    ],
    remainder="drop",
)

# %% [markdown]
# ## 4. Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(
    max_iter=2000,
    n_jobs=-1,
    class_weight="balanced",
)

# %% [markdown]
# ## 5. Train Model

# %%
from sklearn.pipeline import Pipeline

lr_clf = Pipeline(steps=[
    ("prep", preprocess),
    ("model", lr),
])

lr_clf.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/project-2nd/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler(with_mean=False))]),
#                                                   ['reg_days',
#                                                    'num_days_active_w7',
#                                                    'total_secs_w7',
#                                                    'avg_secs_per_day_w7',
#                                                    'std_secs_w7',
#                                                    'num_songs_w7',
#                                                    'avg_songs_per_day_w7',
#                                                    'num_unq_w7', 'num_25_w7',
#                                                    'num_100_w7',
#                                                    'short_play_w7',
#                                                    'skip_ratio_w7',
#                                                    'completion_ratio_w7',
#                                                    'short_play...
#                                                    'short_play_ratio_w14',
#                                                    'variety_ratio_w14',
#                                                    'num_days_active_w21', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['city', 'gender',
#                                                    'registered_via',
#                                                    'last_payment_method',
#                                                    'has_ever_paid',
#                                                    'has_ever_cancelled',
#                                                    'is_auto_renew_last',
#                                                    'is_free_user'])])),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=2000,
#                                     n_jobs=-1))])

# %% [markdown]
# ## 6. Test Evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    average_precision_score,
    recall_score,
    accuracy_score,
    confusion_matrix,
    classification_report,
)

y_proba = lr_clf.predict_proba(X_test)[:, 1]
y_pred  = lr_clf.predict(X_test)

print(f"PR-AUC: {average_precision_score(y_test, y_proba):.4f}")
print(f"Recall (Churn): {recall_score(y_test, y_pred):.4f}")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# PR-AUC: 0.8379
# Recall (Churn): 0.9074
# Accuracy: 0.9342

# %% [markdown]
# ## 7. Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm, index=["Actual 0", "Actual 1"], columns=["Pred 0", "Pred 1"])
# Out:
#           Pred 0  Pred 1
# Actual 0  146089    9815
# Actual 1    1508   14782

# %% [markdown]
# ## 8. Classification Report

# %%
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9898    0.9370    0.9627    155904
#            1     0.6010    0.9074    0.7231     16290
#
#     accuracy                         0.9342    172194
#    macro avg     0.7954    0.9222    0.8429    172194
# weighted avg     0.9530    0.9342    0.9400    172194

# %% [markdown]
# ## 9. Feature Importance (Coefficients)

# %%
feature_names = lr_clf.named_steps["prep"].get_feature_names_out()
coef = lr_clf.named_steps["model"].coef_[0]

imp_lr_df = pd.DataFrame({
    "feature": feature_names,
    "coef": coef,
    "abs_coef": np.abs(coef),
}).sort_values("abs_coef", ascending=False)

imp_lr_df
# Out:
#                            feature      coef  abs_coef
# 70     num__avg_amount_per_payment  3.472008  3.472008
# 144            cat__is_free_user_1  3.371487  3.371487
# 137           cat__has_ever_paid_0  3.371487  3.371487
# 116  cat__last_payment_method_19.0 -2.952837  2.952837
# 121  cat__last_payment_method_26.0  2.804674  2.804674
# 118  cat__last_payment_method_21.0 -2.786257  2.786257
# 143            cat__is_free_user_0 -2.494995  2.494995
# 138           cat__has_ever_paid_1 -2.494995  2.494995
# 130  cat__last_payment_method_35.0  2.346706  2.346706
# 134  cat__last_payment_method_39.0 -2.332817  2.332817
# 127  cat__last_payment_method_32.0  2.164985  2.164985
# 66     num__days_since_last_cancel -1.934351  1.934351
# 142      cat__is_auto_renew_last_1  1.698810  1.698810
# 114  cat__last_payment_method_17.0  1.661819  1.661819
# 74     num__payment_count_last_90d  1.519365  1.519365
# 69          num__total_amount_paid -1.224578  1.224578
# 112  cat__last_payment_method_15.0  1.204185  1.204185
# 111  cat__last_payment_method_14.0 -1.085173  1.085173
# 126  cat__last_payment_method_31.0 -1.034851  1.034851
# 129  cat__last_payment_method_34.0 -1.009562  1.009562
# 73     num__payment_count_last_30d -0.950896  0.950896
# 128  cat__last_payment_method_33.0 -0.922434  0.922434
# 133  cat__last_payment_method_38.0  0.921786  0.921786
# 139      cat__has_ever_cancelled_0  0.917421  0.917421
# 141      cat__is_auto_renew_last_0 -0.822318  0.822318
# 120  cat__last_payment_method_23.0 -0.814548  0.814548
# 123  cat__last_payment_method_28.0  0.806382  0.806382
# 65    num__days_since_last_payment  0.728804  0.728804
# 135  cat__last_payment_method_40.0  0.705615  0.705615
# 136  cat__last_payment_method_41.0  0.652513  0.652513
# 68        num__total_payment_count  0.608435  0.608435
# 100          cat__registered_via_4  0.502806  0.502806
# 72    num__subscription_months_est  0.484277  0.484277
# 107  cat__last_payment_method_10.0  0.439847  0.439847
# 117  cat__last_payment_method_20.0  0.430348  0.430348
# 33              num__num_songs_w21 -0.395932  0.395932
# 35                num__num_unq_w21  0.361292  0.361292
# 93                    cat__city_20 -0.353134  0.353134
# 43        num__num_days_active_w30  0.352179  0.352179
# 108  cat__last_payment_method_11.0 -0.336152  0.336152
# 97                cat__gender_male  0.334738  0.334738
# 89                    cat__city_16  0.321784  0.321784
# 67             num__last_plan_days  0.303243  0.303243
# 20      num__avg_songs_per_day_w14 -0.302798  0.302798
# 9                  num__num_100_w7  0.300121  0.300121
# 132  cat__last_payment_method_37.0 -0.299404  0.299404
# 103         cat__registered_via_13  0.285267  0.285267
# 122  cat__last_payment_method_27.0 -0.282725  0.282725
# 110  cat__last_payment_method_13.0  0.281934  0.281934
# 2               num__total_secs_w7 -0.277641  0.277641
# 98             cat__gender_unknown  0.277614  0.277614
# 80                     cat__city_7  0.275844  0.275844
# 96              cat__gender_female  0.264141  0.264141
# 47              num__num_songs_w30 -0.263563  0.263563
# 131  cat__last_payment_method_36.0  0.260556  0.260556
# 31       num__avg_secs_per_day_w21 -0.248532  0.248532
# 24             num__short_play_w14  0.245633  0.245633
# 17       num__avg_secs_per_day_w14  0.239292  0.239292
# 22                 num__num_25_w14 -0.231388  0.231388
# 0                    num__reg_days  0.228626  0.228626
# 92                    cat__city_19 -0.216516  0.216516
# 109  cat__last_payment_method_12.0  0.214381  0.214381
# 23                num__num_100_w14  0.207716  0.207716
# 21                num__num_unq_w14 -0.188802  0.188802
# 37                num__num_100_w21  0.183401  0.183401
# 77                     cat__city_4  0.179290  0.179290
# 52             num__short_play_w30  0.170225  0.170225
# 115  cat__last_payment_method_18.0 -0.163039  0.163039
# 29        num__num_days_active_w21 -0.158242  0.158242
# 10              num__short_play_w7 -0.152034  0.152034
# 1          num__num_days_active_w7 -0.146951  0.146951
# 8                   num__num_25_w7  0.146649  0.146649
# 26       num__completion_ratio_w14 -0.140951  0.140951
# 51                num__num_100_w30  0.138170  0.138170
# 15        num__num_days_active_w14 -0.131064  0.131064
# 46               num__std_secs_w30  0.127017  0.127017
# 71          num__unique_plan_count -0.126280  0.126280
# 27       num__short_play_ratio_w14 -0.126158  0.126158
# 62        num__songs_trend_w14_w30  0.124524  0.124524
# 82                     cat__city_9  0.122770  0.122770
# 34      num__avg_songs_per_day_w21  0.121521  0.121521
# 81                     cat__city_8  0.120059  0.120059
# 49                num__num_unq_w30 -0.117418  0.117418
# 79                     cat__city_6  0.112634  0.112634
# 78                     cat__city_5  0.108534  0.108534
# 58         num__secs_trend_w14_w30 -0.107763  0.107763
# 44             num__total_secs_w30  0.106534  0.106534
# 95                    cat__city_22  0.104020  0.104020
# 36                 num__num_25_w21  0.095077  0.095077
# 88                    cat__city_15  0.093669  0.093669
# 11              num__skip_ratio_w7 -0.086165  0.086165
# 41       num__short_play_ratio_w21 -0.082027  0.082027
# 3         num__avg_secs_per_day_w7 -0.081017  0.081017
# 99           cat__registered_via_3  0.077947  0.077947
# 40       num__completion_ratio_w21 -0.073115  0.073115
# 101          cat__registered_via_7  0.072074  0.072074
# 86                    cat__city_13  0.071540  0.071540
# 18               num__std_secs_w14 -0.069883  0.069883
# 124  cat__last_payment_method_29.0 -0.068628  0.068628
# 91                    cat__city_18 -0.068418  0.068418
# 83                    cat__city_10  0.064689  0.064689
# 13        num__short_play_ratio_w7  0.062706  0.062706
# 53             num__skip_ratio_w30 -0.062476  0.062476
# 102          cat__registered_via_9 -0.061602  0.061602
# 64    num__completion_trend_w7_w30 -0.058685  0.058685
# 19              num__num_songs_w14  0.057569  0.057569
# 38             num__short_play_w21 -0.055882  0.055882
# 119  cat__last_payment_method_22.0  0.055673  0.055673
# 48      num__avg_songs_per_day_w30  0.054769  0.054769
# 25             num__skip_ratio_w14  0.054366  0.054366
# 59          num__days_trend_w7_w14 -0.052746  0.052746
# 57          num__secs_trend_w7_w30  0.052596  0.052596
# 125  cat__last_payment_method_30.0  0.051585  0.051585
# 55       num__short_play_ratio_w30  0.051352  0.051352
# 87                    cat__city_14  0.046982  0.046982
# 32               num__std_secs_w21 -0.045640  0.045640
# 140      cat__has_ever_cancelled_1 -0.040929  0.040929
# 85                    cat__city_12 -0.038532  0.038532
# 113  cat__last_payment_method_16.0 -0.038310  0.038310
# 54       num__completion_ratio_w30  0.038126  0.038126
# 61         num__songs_trend_w7_w30 -0.036030  0.036030
# 90                    cat__city_17 -0.035868  0.035868
# 28          num__variety_ratio_w14 -0.034923  0.034923
# 63          num__skip_trend_w7_w30 -0.031919  0.031919
# 42          num__variety_ratio_w21 -0.031305  0.031305
# 60          num__days_trend_w7_w30  0.030867  0.030867
# 7                  num__num_unq_w7  0.019635  0.019635
# 76                     cat__city_3 -0.019453  0.019453
# 50                 num__num_25_w30 -0.015342  0.015342
# 30             num__total_secs_w21 -0.013829  0.013829
# 56          num__variety_ratio_w30  0.011482  0.011482
# 75                     cat__city_1 -0.010152  0.010152
# 94                    cat__city_21 -0.010007  0.010007
# 12        num__completion_ratio_w7 -0.009753  0.009753
# 6        num__avg_songs_per_day_w7 -0.009299  0.009299
# 16             num__total_secs_w14 -0.008133  0.008133
# 84                    cat__city_11  0.006755  0.006755
# 45       num__avg_secs_per_day_w30  0.005757  0.005757
# 5                num__num_songs_w7 -0.004426  0.004426
# 39             num__skip_ratio_w21  0.002447  0.002447
# 4                 num__std_secs_w7  0.001927  0.001927
# 14           num__variety_ratio_w7 -0.000886  0.000886
# 106   cat__last_payment_method_8.0  0.000139  0.000139
# 104   cat__last_payment_method_3.0  0.000058  0.000058
# 105   cat__last_payment_method_6.0  0.000042  0.000042

# %%
imp_lr_df.to_csv(
    "../data/model_df/lr_feature_importance.csv",
    index=False
)
