# %% [markdown]
# # Random Forest Classifier Baseline (Model Comparison) v3
#
# - 모델 종류 체급 비교 목적
#
# 평가 (Test set):
# - PR-AUC
# - Recall (Churn)
# - Accuracy
# - Confusion Matrix
# - Classification Report
# - Feature Importance

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_parquet('../data/processed/kkbox_train_feature_v3.parquet')

# %%
RANDOM_STATE = 719

ID_COL = "msno"
TARGET_COL = "is_churn"

CATEGORICAL_COLS = [
    "city", "gender", "registered_via", "last_payment_method",
    "has_ever_paid", "has_ever_cancelled", "is_auto_renew_last", "is_free_user",
]

NUMERICAL_COLS = [
    "reg_days",
    "num_days_active_w7", "total_secs_w7", "avg_secs_per_day_w7", "std_secs_w7",
    "num_songs_w7", "avg_songs_per_day_w7", "num_unq_w7", "num_25_w7", "num_100_w7",
    "short_play_w7", "skip_ratio_w7", "completion_ratio_w7", "short_play_ratio_w7", "variety_ratio_w7",
    "num_days_active_w14", "total_secs_w14", "avg_secs_per_day_w14", "std_secs_w14",
    "num_songs_w14", "avg_songs_per_day_w14", "num_unq_w14", "num_25_w14", "num_100_w14",
    "short_play_w14", "skip_ratio_w14", "completion_ratio_w14", "short_play_ratio_w14", "variety_ratio_w14",
    "num_days_active_w21", "total_secs_w21", "avg_secs_per_day_w21", "std_secs_w21",
    "num_songs_w21", "avg_songs_per_day_w21", "num_unq_w21", "num_25_w21", "num_100_w21",
    "short_play_w21", "skip_ratio_w21", "completion_ratio_w21", "short_play_ratio_w21", "variety_ratio_w21",
    "num_days_active_w30", "total_secs_w30", "avg_secs_per_day_w30", "std_secs_w30",
    "num_songs_w30", "avg_songs_per_day_w30", "num_unq_w30", "num_25_w30", "num_100_w30",
    "short_play_w30", "skip_ratio_w30", "completion_ratio_w30", "short_play_ratio_w30", "variety_ratio_w30",
    "secs_trend_w7_w30", "secs_trend_w14_w30", "days_trend_w7_w14", "days_trend_w7_w30",
    "songs_trend_w7_w30", "songs_trend_w14_w30", "skip_trend_w7_w30", "completion_trend_w7_w30",
    "days_since_last_payment", "days_since_last_cancel", "last_plan_days",
    "total_payment_count", "total_amount_paid", "avg_amount_per_payment",
    "unique_plan_count", "subscription_months_est", "payment_count_last_30d", "payment_count_last_90d",
]

FEATURE_COLS = CATEGORICAL_COLS + NUMERICAL_COLS

X = df[FEATURE_COLS].copy()
y = df[TARGET_COL].astype(int).copy()

# %% [markdown]
# ## 1. Train / Test Split

# %%
from sklearn.model_selection import train_test_split

X = df[FEATURE_COLS]
y = df[TARGET_COL].astype(int)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=y,
)

print(X_train.shape, X_test.shape)
# Out:
# (688772, 83) (172194, 83)

# %% [markdown]
# ## 2. Column Groups

# %%
cat_cols = [c for c in CATEGORICAL_COLS if c in X_train.columns]
num_cols = [c for c in NUMERICAL_COLS if c in X_train.columns]

print(f"num_cols: {len(num_cols)}")
print(f"cat_cols: {len(cat_cols)}")
# Out:
# num_cols: 75
# cat_cols: 8

# %% [markdown]
# ## 3. Preprocessing (OHE only)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

X_train_t = preprocess.fit_transform(X_train)
X_test_t = preprocess.transform(X_test)

# %% [markdown]
# ## 4. Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=800,
    max_depth=None,
    max_features="sqrt",
    min_samples_split=2,
    min_samples_leaf=1,
    class_weight="balanced",
    n_jobs=-1,
    random_state=RANDOM_STATE,
)

# %% [markdown]
# ## 5. Train Model

# %%
rf_model.fit(X_train_t, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=800, n_jobs=-1,
#                        random_state=719)

# %% [markdown]
# ## 6. Test Evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    average_precision_score,
    recall_score,
    accuracy_score,
    confusion_matrix,
    classification_report,
)

y_proba = rf_model.predict_proba(X_test_t)[:, 1]
y_pred  = rf_model.predict(X_test_t)

print(f"PR-AUC: {average_precision_score(y_test, y_proba):.4f}")
print(f"Recall (Churn): {recall_score(y_test, y_pred):.4f}")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# PR-AUC: 0.9236
# Recall (Churn): 0.8114
# Accuracy: 0.9729

# %% [markdown]
# ## 7. Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
pd.DataFrame(cm, index=["Actual 0", "Actual 1"], columns=["Pred 0", "Pred 1"])
# Out:
#           Pred 0  Pred 1
# Actual 0  154317    1587
# Actual 1    3072   13218

# %% [markdown]
# ## 8. Classification Report

# %%
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9805    0.9898    0.9851    155904
#            1     0.8928    0.8114    0.8502     16290
#
#     accuracy                         0.9729    172194
#    macro avg     0.9366    0.9006    0.9176    172194
# weighted avg     0.9722    0.9729    0.9724    172194

# %% [markdown]
# ## 9. Feature Importance (Impurity Decrease)

# %%
feature_names = preprocess.get_feature_names_out()
importances = rf_model.feature_importances_

imp_rf_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances,
}).sort_values("importance", ascending=False)

imp_rf_df
# Out:
#                            feature    importance
# 66     num__days_since_last_cancel  7.525890e-02
# 140      cat__has_ever_cancelled_1  7.473436e-02
# 69          num__total_amount_paid  7.050704e-02
# 139      cat__has_ever_cancelled_0  6.611499e-02
# 72    num__subscription_months_est  6.034646e-02
# 74     num__payment_count_last_90d  6.009984e-02
# 142      cat__is_auto_renew_last_1  4.590935e-02
# 141      cat__is_auto_renew_last_0  4.524888e-02
# 70     num__avg_amount_per_payment  4.164033e-02
# 68        num__total_payment_count  4.070052e-02
# 65    num__days_since_last_payment  3.809081e-02
# 73     num__payment_count_last_30d  3.548130e-02
# 137           cat__has_ever_paid_0  1.789523e-02
# 67             num__last_plan_days  1.750084e-02
# 144            cat__is_free_user_1  1.437997e-02
# 0                    num__reg_days  1.404068e-02
# 143            cat__is_free_user_0  1.392970e-02
# 138           cat__has_ever_paid_1  1.342879e-02
# 71          num__unique_plan_count  1.007946e-02
# 101          cat__registered_via_7  7.385581e-03
# 61         num__songs_trend_w7_w30  5.772874e-03
# 60          num__days_trend_w7_w30  5.628999e-03
# 57          num__secs_trend_w7_w30  5.594410e-03
# 136  cat__last_payment_method_41.0  5.573644e-03
# 2               num__total_secs_w7  5.235037e-03
# 134  cat__last_payment_method_39.0  4.676964e-03
# 5                num__num_songs_w7  4.517562e-03
# 3         num__avg_secs_per_day_w7  4.506135e-03
# 6        num__avg_songs_per_day_w7  4.501406e-03
# 59          num__days_trend_w7_w14  4.173795e-03
# 64    num__completion_trend_w7_w30  4.096187e-03
# 14           num__variety_ratio_w7  4.092552e-03
# 7                  num__num_unq_w7  3.939775e-03
# 62        num__songs_trend_w14_w30  3.915393e-03
# 58         num__secs_trend_w14_w30  3.878150e-03
# 9                  num__num_100_w7  3.537092e-03
# 56          num__variety_ratio_w30  3.485800e-03
# 63          num__skip_trend_w7_w30  3.457547e-03
# 46               num__std_secs_w30  3.396308e-03
# 28          num__variety_ratio_w14  3.213428e-03
# 42          num__variety_ratio_w21  3.195811e-03
# 16             num__total_secs_w14  3.184401e-03
# 45       num__avg_secs_per_day_w30  3.152474e-03
# 49                num__num_unq_w30  3.146555e-03
# 44             num__total_secs_w30  3.110337e-03
# 48      num__avg_songs_per_day_w30  3.068998e-03
# 17       num__avg_secs_per_day_w14  3.055910e-03
# 54       num__completion_ratio_w30  3.053760e-03
# 47              num__num_songs_w30  3.030222e-03
# 12        num__completion_ratio_w7  3.025232e-03
# 21                num__num_unq_w14  2.990228e-03
# 32               num__std_secs_w21  2.962052e-03
# 19              num__num_songs_w14  2.952490e-03
# 4                 num__std_secs_w7  2.915862e-03
# 18               num__std_secs_w14  2.875292e-03
# 53             num__skip_ratio_w30  2.869475e-03
# 51                num__num_100_w30  2.848042e-03
# 31       num__avg_secs_per_day_w21  2.844866e-03
# 55       num__short_play_ratio_w30  2.838744e-03
# 20      num__avg_songs_per_day_w14  2.818385e-03
# 127  cat__last_payment_method_32.0  2.814388e-03
# 75                     cat__city_1  2.788746e-03
# 23                num__num_100_w14  2.759152e-03
# 34      num__avg_songs_per_day_w21  2.743936e-03
# 30             num__total_secs_w21  2.731404e-03
# 11              num__skip_ratio_w7  2.727792e-03
# 27       num__short_play_ratio_w14  2.723281e-03
# 13        num__short_play_ratio_w7  2.713139e-03
# 52             num__short_play_w30  2.702538e-03
# 40       num__completion_ratio_w21  2.688951e-03
# 35                num__num_unq_w21  2.686409e-03
# 26       num__completion_ratio_w14  2.668790e-03
# 25             num__skip_ratio_w14  2.666295e-03
# 39             num__skip_ratio_w21  2.620417e-03
# 50                 num__num_25_w30  2.591243e-03
# 8                   num__num_25_w7  2.590341e-03
# 41       num__short_play_ratio_w21  2.536422e-03
# 33              num__num_songs_w21  2.518908e-03
# 37                num__num_100_w21  2.471887e-03
# 38             num__short_play_w21  2.337891e-03
# 36                 num__num_25_w21  2.318774e-03
# 10              num__short_play_w7  2.316207e-03
# 43        num__num_days_active_w30  2.263747e-03
# 24             num__short_play_w14  2.212484e-03
# 22                 num__num_25_w14  2.199593e-03
# 135  cat__last_payment_method_40.0  2.129406e-03
# 131  cat__last_payment_method_36.0  2.046121e-03
# 98             cat__gender_unknown  1.881048e-03
# 1          num__num_days_active_w7  1.852733e-03
# 133  cat__last_payment_method_38.0  1.851470e-03
# 29        num__num_days_active_w21  1.635144e-03
# 15        num__num_days_active_w14  1.577418e-03
# 102          cat__registered_via_9  1.280565e-03
# 100          cat__registered_via_4  1.061222e-03
# 132  cat__last_payment_method_37.0  9.889490e-04
# 124  cat__last_payment_method_29.0  8.130835e-04
# 96              cat__gender_female  7.502173e-04
# 97                cat__gender_male  7.148391e-04
# 99           cat__registered_via_3  7.134884e-04
# 86                    cat__city_13  5.544738e-04
# 78                     cat__city_5  5.184462e-04
# 112  cat__last_payment_method_15.0  5.020342e-04
# 77                     cat__city_4  4.492515e-04
# 95                    cat__city_22  4.342078e-04
# 88                    cat__city_15  3.922738e-04
# 125  cat__last_payment_method_30.0  3.442252e-04
# 79                     cat__city_6  3.093844e-04
# 129  cat__last_payment_method_34.0  2.738692e-04
# 87                    cat__city_14  2.328410e-04
# 81                     cat__city_8  1.969373e-04
# 128  cat__last_payment_method_33.0  1.839165e-04
# 82                     cat__city_9  1.827834e-04
# 84                    cat__city_11  1.693312e-04
# 85                    cat__city_12  1.655779e-04
# 91                    cat__city_18  1.528272e-04
# 117  cat__last_payment_method_20.0  1.313265e-04
# 83                    cat__city_10  1.291681e-04
# 94                    cat__city_21  1.252343e-04
# 90                    cat__city_17  1.181689e-04
# 76                     cat__city_3  1.171390e-04
# 126  cat__last_payment_method_31.0  9.059193e-05
# 80                     cat__city_7  8.149164e-05
# 118  cat__last_payment_method_21.0  6.944839e-05
# 122  cat__last_payment_method_27.0  6.069590e-05
# 123  cat__last_payment_method_28.0  5.609556e-05
# 89                    cat__city_16  4.921459e-05
# 113  cat__last_payment_method_16.0  4.702408e-05
# 119  cat__last_payment_method_22.0  4.185458e-05
# 103         cat__registered_via_13  3.812554e-05
# 116  cat__last_payment_method_19.0  3.785567e-05
# 120  cat__last_payment_method_23.0  3.626280e-05
# 130  cat__last_payment_method_35.0  2.960893e-05
# 93                    cat__city_20  1.986764e-05
# 107  cat__last_payment_method_10.0  1.789746e-05
# 114  cat__last_payment_method_17.0  1.609919e-05
# 110  cat__last_payment_method_13.0  1.017004e-05
# 121  cat__last_payment_method_26.0  5.214209e-06
# 92                    cat__city_19  4.685030e-06
# 108  cat__last_payment_method_11.0  3.633459e-06
# 109  cat__last_payment_method_12.0  3.121937e-06
# 115  cat__last_payment_method_18.0  2.280990e-06
# 111  cat__last_payment_method_14.0  1.666100e-06
# 106   cat__last_payment_method_8.0  1.067902e-19
# 104   cat__last_payment_method_3.0  7.959882e-20
# 105   cat__last_payment_method_6.0  5.127818e-20

# %%
imp_rf_df.to_csv(
    "../data/model_df/rf_feature_importance.csv",
    index=False
)
